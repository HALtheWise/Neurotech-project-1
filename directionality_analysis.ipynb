# %%
import numpy as np
# %run 'parse.ipynb'
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
s1 = parse(subj=1)
s2 = parse(subj=2)

# %%
#for k,v in s1.iteritems():
#    print(k, v.columns.values)
    
#s1['Post_RS']
rs1 = s1['Pre_RS'].as_matrix()[1:, 1:]
rs1_post = s1['Post_RS'].as_matrix()[1:, 1:]
rs2 = s2['Pre_RS'].as_matrix()[1:, 1:]
rs2_post = s2['Post_RS'].as_matrix()[1:, 1:]

print(np.max(rs1))
print(np.min(rs1))

plt.imshow((rs1 + 1.0)/2) #0-1
plt.show()

# plt.imshow((rs1_post + 1.0)/2) #0-1
# plt.show()

plt.imshow((rs2 + 1.0)/2) #0-1
plt.show()

# plt.imshow((rs2_post + 1.0)/2) #0-1
# plt.show()

rs1 = s1['Pre_FS'].as_matrix()[1:, 1:]
rs1_post = s1['Post_FS'].as_matrix()[1:, 1:]
rs2 = s2['Pre_FS'].as_matrix()[1:, 1:]
rs2_post = s2['Post_FS'].as_matrix()[1:, 1:]

print(np.max(rs1))
print(np.min(rs1))

plt.imshow((rs1 + 1.0)/2) #0-1
plt.show()

plt.imshow((rs1_post + 1.0)/2) #0-1
plt.show()

plt.imshow((rs2 + 1.0)/2) #0-1
plt.show()

plt.imshow((rs2_post + 1.0)/2) #0-1
plt.show()

# rs1 = cv2.applyColorMap((255*rs1).astype(np.uint8), cv2.COLORMAP_JET)
# plt.imshow(rs1)
# plt.show()

# rs2 = cv2.applyColorMap((255*rs2).astype(np.uint8), cv2.COLORMAP_JET)
# plt.imshow(rs2)
# plt.show()

#cv2.imshow('rs1', rs1)
#s1.keys()
#s1['Pre_RS']
# Out:
# 1.0
# -0.89582
# 2130.83014049
# 0.0
